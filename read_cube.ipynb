# %% [markdown]
# ## Example on how to read a fits cube with python

# %%
import pyfits as fits
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cube = fits.open('data/fits/NGC0309_inla.fits')
cube.info()
# Out:
# Filename: data/fits/NGC0309_inla.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU      25   (74, 72, 12)   float64

# %%
image = np.arcsinh(cube[0].data[0]) #mass
mask = (image > 0)
fig, ax = plt.subplots(figsize = (10, 10))
l1, l2 = (np.percentile(image[mask].flatten(), 10), np.percentile(image[mask].flatten(), 90))
color = ax.imshow(image,clim=(l1,l2));
fig.colorbar(color)
# Out:
# /home/santiago/Programs/miniconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: RuntimeWarning: invalid value encountered in greater
#   from ipykernel import kernelapp as app
